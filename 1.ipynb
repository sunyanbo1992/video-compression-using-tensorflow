# %%
import numpy as np
import cv2

cap = cv2.VideoCapture('MediaCoder_test1_1m9s_AVC_VBR_256kbps_640x480_24fps_MPEG2Layer3_CBR_160kbps_Stereo_22050Hz.mp4')

# Define the codec and create VideoWriter object
fourcc = cv2.cv.CV_FOURCC(*'XVID')
out = cv2.VideoWriter('test1.avi',fourcc, 40.0, (50,50))
k = 0
while k < 100:
    ret, frame = cap.read()
    k += 1
    if ret==True:
        #frame = cv2.flip(frame,0)
        # write the flipped frame
        #gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        #gray = cv2.resize(gray, (50,50))
        out.write(frame)
        frame = cv2.resize(frame, (50,50))

        cv2.imshow('frame',frame)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    else:
        break

# Release everything if job is finished
cap.release()
out.release()
cv2.destroyAllWindows()

# %%
import numpy as np
import cv2
cap = cv2.VideoCapture("/home/lenovo3/1/experiment_e=0.00001/foreman.mp4.nn.mp4")
ret, frame = cap.read()
if ret == True:
    cv2.imwrite("/home/lenovo3/foreman1.jpg", frame)
cap.release()

# %%
csvfile = file('/media/sunyanbo/41A2-A27B/downloads/test2.txt', 'wb')
spamwrite = csv.writer(csvfile)
l = canvas.reshape(1,400)[0]
g = [m/255 for m in l]
spamwrite.writerow(g)

# %%
import numpy as np 
import cv2 

#canvas = np.zeros((50,50),dtype="uint8")
#files = open('/media/sunyanbo/41A2-A27B/downloads/experiment5.txt', 'wb')
#writer = csv.writer(csvfile, delimiter = ',', dialect = 'excel')
import csv
#files = open('/media/sunyanbo/41A2-A27B/downloads/test.txt', 'w')

csvfile = file('/media/sunyanbo/41A2-A27B/downloads/test.txt', 'wb')
i = 0
#with open('/media/sunyanbo/41A2-A27B/downloads/experiment5.txt', 'wb') as files:
spamwrite = csv.writer(csvfile)
while i < 11:
    canvas = np.ones((20,20),dtype="uint8")*255
    cv2.rectangle(canvas,(i,0),(i + 8, 8),0,-1)
    i += 1
            #canvas = cv2.resize(canvas, (30,30))
            #cv2.imshow("Canvas",canvas)
            #cv2.imwrite('/home/sunyanbo/experiment3/%d.jpg'%i,canvas)
    l = canvas.reshape(1,400)[0]
    g = [m/255 for m in l]
            #canvas.reshape(1,400)[0]
    #g = [r[0]/255 for r in l]
            #s = ','.join([str(m / 255) for m in g])
            #files.write(s + "\n")
    spamwrite.writerow(g)
i = 0
while i < 11:
    canvas = np.ones((20,20),dtype="uint8")*255
    cv2.rectangle(canvas,(11,i),(19, i+8),0,-1)
    i += 1
            #canvas = cv2.resize(canvas, (30,30))
            #cv2.imshow("Canvas",canvas)
            #cv2.imwrite('/home/sunyanbo/experiment3/%d.jpg'%(i+11),canvas)
    #l = cv2.resize(canvas, (1,400))
    l = canvas.reshape(1,400)[0]
    g = [m/255 for m in l]
    #g = [r[0]/255 for r in l]
            #s = ','.join([str(m / 255) for m in g])
            #files.write(s + "\n")
        #spamwrite = csv.writer(files)
    spamwrite.writerow(g)
i = 0
while i < 11:
    canvas = np.ones((20,20),dtype="uint8")*255
    cv2.rectangle(canvas,(11-i,11),(19-i,19),0,-1)
    i += 1
            #canvas = cv2.resize(canvas, (30,30))
            #cv2.imshow("Canvas",canvas)
            #cv2.imwrite('/home/sunyanbo/experiment3/%d.jpg'%(i+22),canvas)
    #l = cv2.resize(canvas, (1,400))
    l = canvas.reshape(1,400)[0]
    g = [m/255 for m in l]
    #g = [r[0]/255 for r in l]
            #s = ','.join([str(m / 255) for m in g])
            #files.write(s + "\n")
        #spamwrite = csv.writer(files)
    spamwrite.writerow(g)
i = 0
while i < 11:
    canvas = np.ones((20,20),dtype="uint8")*255
    cv2.rectangle(canvas,(0,11-i),(8,19-i),0,-1)
    i += 1
            #canvas = cv2.resize(canvas, (30,30))
            #cv2.imshow("Canvas",canvas)
            #cv2.imwrite('/home/sunyanbo/experiment3/%d.jpg'%(i+33),canvas)
    #l = cv2.resize(canvas, (1,400))
    l = canvas.reshape(1,400)[0]
    g = [m/255 for m in l]
    #g = [r[0]/255 for r in l]
            #s = ','.join([str(m / 255) for m in g])
            #files.write(s + "\n")
        #spamwrite = csv.writer(files)
    spamwrite.writerow(g)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-65-26ae8c1db19b> in <module>()
#      74         #spamwrite = csv.writer(files)
#      75     spamwrite.writerow(g)
# ---> 76 cv2.waitKey(0)
#      77 cv2.destroyAllWindows()
#
# KeyboardInterrupt:

# %%
cv2.namedWindow('image')

# %%
import numpy as np 
import cv2 
#canvas = np.zeros((50,50),dtype="uint8")
i = 0
while i < 5:
    canvas = np.ones((10,10),dtype="uint8")*255
    cv2.rectangle(canvas,(i,0),(i + 4, 4),0,-1)
    i += 1
    #canvas = cv2.resize(canvas, (30,30))
    cv2.imshow("Canvas",canvas)
    
    cv2.imwrite('/home/sunyanbo/experiment1/%d.jpg'%i,canvas)
i = 0
while i < 5:
    canvas = np.ones((10,10),dtype="uint8")*255
    cv2.rectangle(canvas,(5,i),(9, i+4),0,-1)
    i += 1
    #canvas = cv2.resize(canvas, (30,30))
    cv2.imshow("Canvas",canvas)
    cv2.imwrite('/home/sunyanbo/experiment1/%d.jpg'%(i+5),canvas)
i = 0
while i < 5:
    canvas = np.ones((10,10),dtype="uint8")*255
    cv2.rectangle(canvas,(5-i,5),(9-i,9),0,-1)
    i += 1
    #canvas = cv2.resize(canvas, (30,30))
    cv2.imshow("Canvas",canvas)
    cv2.imwrite('/home/sunyanbo/experiment1/%d.jpg'%(i+10),canvas)
i = 0
while i < 5:
    canvas = np.ones((10,10),dtype="uint8")*255
    cv2.rectangle(canvas,(0,5-i),(4,9-i),0,-1)
    i += 1
    #canvas = cv2.resize(canvas, (30,30))
    cv2.imshow("Canvas",canvas)
    cv2.imwrite('/home/sunyanbo/experiment1/%d.jpg'%(i+15),canvas)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import numpy as np 
import cv2 
#canvas = np.zeros((50,50),dtype="uint8")
i = 0
while i < 79:
    canvas = np.ones((100,100),dtype="uint8")*255
    cv2.rectangle(canvas,(i,0),(i + 20, 20),0,-1)
    i += 1
    canvas = cv2.resize(canvas, (30,30))
    cv2.imshow("Canvas",canvas)
    
    cv2.imwrite('/home/sunyanbo/test30x30/%d.jpg'%i,canvas)
i = 0
while i < 79:
    canvas = np.ones((100,100),dtype="uint8")*255
    cv2.rectangle(canvas,(79,i),(99, i+20),0,-1)
    i += 1
    canvas = cv2.resize(canvas, (30,30))
    cv2.imshow("Canvas",canvas)
    cv2.imwrite('/home/sunyanbo/test30x30/%d.jpg'%(i+79),canvas)
i = 0
while i < 79:
    canvas = np.ones((100,100),dtype="uint8")*255
    cv2.rectangle(canvas,(79-i,79),(99-i,99),0,-1)
    i += 1
    canvas = cv2.resize(canvas, (30,30))
    cv2.imshow("Canvas",canvas)
    cv2.imwrite('/home/sunyanbo/test30x30/%d.jpg'%(i+158),canvas)
i = 0
while i < 79:
    canvas = np.ones((100,100),dtype="uint8")*255
    cv2.rectangle(canvas,(0,79-i),(20,99-i),0,-1)
    i += 1
    canvas = cv2.resize(canvas, (30,30))
    cv2.imshow("Canvas",canvas)
    cv2.imwrite('/home/sunyanbo/test30x30/%d.jpg'%(i+237),canvas)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
fourcc = cv2.cv.CV_FOURCC(*'XVID')
#cv2.cv.CV_FOURCC('I', 'Y', 'U', 'V')
out = cv2.VideoWriter('/media/sunyanbo/41A2-A27B/RAE_experiments/experiment10/sample_video.avi',cv2.cv.CV_FOURCC('M', 'J', 'P', 'G'), 20, (30,30))
k = 0
while k < 99:
    frame = cv2.imread('/media/sunyanbo/41A2-A27B/RAE_experiments/experiment10/%d.jpg'%k)
    k += 1
    out.write(frame)
    #print k
    cv2.imshow('frame', frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
out.release()
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np
import csv

csvfile = file('csv_test.csv', 'wb')
writer = csv.writer(csvfile)
k = 1
b = []
files = open('/home/lenovo3/3/butter.txt', 'w')
while k < 199:
    #l = []
    frame = cv2.imread('/media/sunyanbo/41A2-A27B/original/%d.jpg'%k)
    #print frame
    #for i in frame:
    #    for j in i:
    #        l.append(j[0])
    l = cv2.split(frame)[0]

    #print len(l), len(l[0])
    l = l.reshape(1,4800)
    #print len(l[0])
    #print frame
    #frame = frame.tolist()
    #for x in frame:
    #    t.append(x)
    #print l
    x = [str(m / 255) for m in l[0]]
    s = ','.join([str(m / 255) for m in l[0]])
    #print len(s)
    #print len(s.strip().split(','))
    k += 1
    writer.writerow(tuple(x))

# %%
import cv2
import numpy as np
video = []
lines = open('/home/sunyanbo/sample_output.txt').readlines()
for line in lines:
    a = []
    #print line[0]
    line = line.strip().split(',')
    #print line
    #print line[0]
    if len(line) != 10000:
        continue
    for i in line:
        a.append(int(float(i) * 255.0))
    #print len(a)
    #print len(a)
    #print np.array(a)
    images = np.array(a).reshape(100,100)
   # print len(images)
    #images.dtype = 'uint8'
    #print len(images[0])
    video.append(images)
video = np.array(video)

# %%
cv2.cv.CV_FOURCC('m','p','4','v')
#fourcc = cv2.videowriter_fourcc(*'XVID')
j = 0
for frames in video:
    cv2.imwrite('/home/sunyanbo/sample1/%d.jpg'%j, frames)
    j += 1

# %%
import numpy as np 
import cv2
import csv
#canvas = np.zeros((50,50),dtype="uint8")
#files = open('/media/sunyanbo/41A2-A27B/downloads/5.txt', 'w')
csvfile = file('/media/sunyanbo/41A2-A27B/downloads/random.txt', 'wb')
spamwrite = csv.writer(csvfile)
i = 0
while i < 24:
    canvas = np.zeros((30,30),dtype="uint8")
    cv2.rectangle(canvas,(i,0),(i + 5, 5),255,-1)
    #cv2.resize(canvas, (50,50))
    #cv2.imshow("Canvas",canvas)
    i += 1
    cv2.imwrite('/home/sunyanbo/experiment5/%d.jpg'%i,canvas)
    #s = ','.join([str(m / 255) for m in l])
    l = canvas.reshape(1,900)[0]
    g = [m/255 for m in l]
    spamwrite.writerow(tuple(g))
    #files.write(s + "\n")
i = 0
while i < 24:
    canvas = np.ones((30,30),dtype="uint8")
    cv2.rectangle(canvas,(24,i),(29, i+5),255,-1)
    #cv2.resize(canvas, (50,50))
    i += 1
    #cv2.imshow("Canvas",canvas)
    cv2.imwrite('/home/sunyanbo/experiment5/%d.jpg'%(i+24),canvas)
    l = canvas.reshape(1,900)[0]
    g = [m/255 for m in l]
    spamwrite.writerow(tuple(g))
    #s = ','.join([str(m / 255) for m in l])
    #files.write(s + "\n")
i = 0
while i < 24:
    canvas = np.ones((30,30),dtype="uint8")
    cv2.rectangle(canvas,(24-i,24),(29-i,29),255,-1)
    i += 1
    #cv2.imshow("Canvas",canvas)
    cv2.imwrite('/home/sunyanbo/experiment5/%d.jpg'%(i+48),canvas)
    l = canvas.reshape(1,900)[0]
    g = [m/255 for m in l]
    spamwrite.writerow(tuple(g))
    #s = ','.join([str(m / 255) for m in l])
    #files.write(s + "\n")
i = 0
while i < 24:
    canvas = np.ones((30,30),dtype="uint8")
    cv2.rectangle(canvas,(0,24-i),(5,29-i),255,-1)
    i += 1
    #cv2.imshow("Canvas",canvas)
    cv2.imwrite('/home/sunyanbo/experiment5/%d.jpg'%(i+72),canvas)
    l = canvas.reshape(1,900)[0]
    g = [m/255 for m in l]
    spamwrite.writerow(tuple(g))
    #s = ','.join([str(m / 255) for m in l])
    #print s
    #files.write(s + "\n")
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-326663fb9463> in <module>()
#      57     #print s
#      58     #files.write(s + "\n")
# ---> 59 cv2.waitKey(0)
#      60 cv2.destroyAllWindows()
#
# KeyboardInterrupt:

# %%
import numpy as np 
import cv2
import csv
import random
#canvas = np.zeros((50,50),dtype="uint8")
#files = open('/media/sunyanbo/41A2-A27B/downloads/5.txt', 'w')
csvfile = file('/media/sunyanbo/41A2-A27B/downloads/random1.txt', 'wb')
spamwrite = csv.writer(csvfile)
i = 0
while i < 100:
    j = random.randint(0,25)
    k = random.randint(0,25)
    canvas = np.ones((30,30),dtype="uint8")*255
    cv2.rectangle(canvas,(j,k),(j + 5, k + 5),0,-1)
    #cv2.resize(canvas, (50,50))
    #cv2.imshow("Canvas",canvas)
    i += 1
    cv2.imwrite('/media/sunyanbo/41A2-A27B/downloads/random1/%d.jpg'%i,canvas)
    #s = ','.join([str(m / 255) for m in l])
    l = canvas.reshape(1,900)[0]
    g = [m/255 for m in l]
    spamwrite.writerow(tuple(g))
    #files.write(s + "\n")
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-751960e11029> in <module>()
#      22     spamwrite.writerow(tuple(g))
#      23     #files.write(s + "\n")
# ---> 24 cv2.waitKey(0)
#      25 cv2.destroyAllWindows()
#
# KeyboardInterrupt:
